# %%
import random
import numpy as np
import pandas as pd
from pathlib import Path

import matplotlib.pyplot as plt

import xgi

import analysis
import hyperplot

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
data = analysis.load_eating_dataset(Path.cwd() / 'data/EatingDisorders.mat')
# Out:
# Adding data info...
# shape: (2302, 32)
# Adding hypergraph info...
# >>> RED
# Retrieving edges...
# Order: 3 | ixs: [2936 4942 4796 4797 4848 1333 4944 4943 4812 4940]
# Order: 4 | ixs: [35638 35950 35948 35946 25349 35631 25353 12560 27087 35945]
# Order: 5 | ixs: [201370 201372 201373 200914 167717 181017 175032 167715 181015 175030]
# Order: 6 | ixs: [906191 772908 831573 805239 851922 805242 805241 851925 831576 831575]
# Retrieving edge values...
# Order: 3 | vals: [1.05976011 1.03180115 0.93409148 0.91521247 0.88942039 0.8639903
#  0.84810606 0.84537592 0.829338   0.80798063]
# Order: 4 | vals: [1.98146965 1.94098469 1.91378006 1.90965085 1.77230347 1.76086678
#  1.7599108  1.73357339 1.72488247 1.72363904]
# Order: 5 | vals: [2.86766856 2.83227196 2.82807484 2.81031282 2.64811012 2.63850615
#  2.63819729 2.63566771 2.63073444 2.6287165 ]
# Order: 6 | vals: [3.79249651 3.63032624 3.61195956 3.60621034 3.60492894 3.56157997
#  3.55770304 3.55428057 3.55229995 3.55023337]
# ...

# %%
data = analysis.load_empathy_dataset(Path.cwd() / 'data/Briganti2017.mat')
# Out:
# Adding data info...
# shape: (1973, 28)
# Adding hypergraph info...
# >>> RED
# Retrieving edges...
# Order: 3 | ixs: [3043 1492 1433 1571 1150 1436  385 1379  576 1382 1154 1152 3184 2644
#  2703 2877  490 1066 2780  496 2783 2813  641 2207 2205 2272 1676  574
#  1372  578 2858 2209 1947  391 2647 2400 1217 1070 1999  498 2860  389
#  2396  380 2425 2592 1574 1578 1200  393 1278 2253 1198 1074 1820  494
#   279 2132 2145 2255  622 2156 3121 1072  768 1728 1874  514 2164 3103
#  1672 1289 2162 2147 3207  487 3243  338 1474 1996 2360 1484 3022 1695
#  2398 2170 2496 2160  525 3025 1964 2402 1101 3035  282  624  486 2561
#  1471 1992]
# Order: 4 | ixs: [11387 18422 11047 10988  2692 19911  3399 19947  3401 14257 10991  9431
#   8778  9433  4456  3315  3403  5126 12284 11551 11587 19018  9450  1141
#  10218  1082 16200 12280  8780 11379  5107 10277 11366  8782  4521  4458
#   4454 16181 19319 10164  3466 16183  3321 11369  5109  8845  9067  4502
# ...

# %%
import networkx as nx

# %%
nx.spring_layout()

# %%
axs = plt.subplots(1, 2)

# %%
plot_polygons(data, internode_dists=[1.6, None], show_nodelabels=True, **{'node_size':0.035})
plt.suptitle('Empathy Dataset')
plt.savefig("empathy_polygons.png", dpi=200)
# Out:
# Optimal internode distance: 0.18
